# %% [markdown]
# # HM2: Numerical Optimization for Logistic Regression.
#
# ### Name: [Ethan Irby]

# %% [markdown]
# ## 0. You will do the following:
#
# 1. Read the lecture note: [click here](https://github.com/wangshusen/DeepLearning/blob/master/LectureNotes/Logistic/paper/logistic.pdf)
#
# 2. Read, complete, and run my code.
#
# 3. **Implement mini-batch SGD** and evaluate the performance.
#
# 4. Convert the .IPYNB file to .HTML file.
#
#     * The HTML file must contain **the code** and **the output after execution**.
#
#     * Missing **the output after execution** will not be graded.
#
# 5. Upload this .HTML file to your Google Drive, Dropbox, or your Github repo.  (If you submit the file to Google Drive or Dropbox, you must make the file "open-access". The delay caused by "deny of access" may result in late penalty.)
#
# 6. Submit the link to this .HTML file to Canvas.
#
#     * Example: https://github.com/wangshusen/CS583-2020S/blob/master/homework/HM2/HM2.html
#
#
# ## Grading criteria:
#
# 1. When computing the ```gradient``` and ```objective function value``` using a batch of samples, use **matrix-vector multiplication** rather than a FOR LOOP of **vector-vector multiplications**.
#
# 2. Plot ```objective function value``` against ```epochs```. In the plot, compare GD, SGD, and MB-SGD (with $b=8$ and $b=64$). The plot must look reasonable.

# %% [markdown]
# # 1. Data processing
#
# - Download the Diabete dataset from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/diabetes
# - Load the data using sklearn.
# - Preprocess the data.

# %% [markdown]
# ## 1.1. Load the data

# %%
from sklearn import datasets
import numpy

x_sparse, y = datasets.load_svmlight_file('diabetes')
x = x_sparse.todense()

print('Shape of x: ' + str(x.shape))
print('Shape of y: ' + str(y.shape))
# Out:
# Shape of x: (768, 8)
# Shape of y: (768,)

# %% [markdown]
# ## 1.2. Partition to training and test sets

# %%
# partition the data to training and test sets
n = x.shape[0]
n_train = 640
n_test = n - n_train

rand_indices = numpy.random.permutation(n)
train_indices = rand_indices[0:n_train]
test_indices = rand_indices[n_train:n]

x_train = x[train_indices, :]
x_test = x[test_indices, :]
y_train = y[train_indices].reshape(n_train, 1)
y_test = y[test_indices].reshape(n_test, 1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
print('Shape of y_train: ' + str(y_train.shape))
print('Shape of y_test: ' + str(y_test.shape))
# Out:
# Shape of x_train: (640, 8)
# Shape of x_test: (128, 8)
# Shape of y_train: (640, 1)
# Shape of y_test: (128, 1)

# %% [markdown]
# ## 1.3. Feature scaling

# %% [markdown]
# Use the standardization to trainsform both training and test features

# %%
# Standardization
import numpy as np

# calculate mu and sig using the training set
d = x_train.shape[1]
mu = numpy.mean(x_train, axis=0).reshape(1, d)
sig = numpy.std(x_train, axis=0).reshape(1, d)

# transform the training features
x_train = (x_train - mu) / (sig + 1E-6)

# transform the test features
x_test = (x_test - mu) / (sig + 1E-6)

print('test mean = ')
print(numpy.mean(x_test, axis=0))

print('test std = ')
print(numpy.std(x_test, axis=0))
# Out:
# test mean =
# [[ 0.01346932  0.05977216 -0.07262506  0.18875904 -0.0744583  -0.09899663
#    0.00785485  0.12987032]]
# test std =
# [[1.00572059 1.06285278 1.05110474 1.03460098 0.79037297 1.070581
#   0.92473878 1.158933  ]]

# %% [markdown]
# ## 1.4. Add a dimension of all ones

# %%
n_train, d = x_train.shape
x_train = numpy.concatenate((x_train, numpy.ones((n_train, 1))), axis=1)

n_test, d = x_test.shape
x_test = numpy.concatenate((x_test, numpy.ones((n_test, 1))), axis=1)

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))
# Out:
# Shape of x_train: (640, 9)
# Shape of x_test: (128, 9)

# %% [markdown]
# # 2. Logistic regression model
#
# The objective function is $Q (w; X, y) = \frac{1}{n} \sum_{i=1}^n \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.

# %%
# Calculate the objective function value
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     objective function value (scalar)
def objective(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(-yxw) # n-by-1 matrix
    vec2 = numpy.log(1 + vec1) # n-by-1 matrix
    loss = numpy.mean(vec2) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    return loss + reg

# %%
# initialize w
d = x_train.shape[1]
w = numpy.zeros((d, 1))

# evaluate the objective function value at w
lam = 1E-6
objval0 = objective(w, x_train, y_train, lam)
print('Initial objective function value = ' + str(objval0))
# Out:
# Initial objective function value = 0.6931471805599453

# %% [markdown]
# # 3. Numerical optimization

# %% [markdown]
# ## 3.1. Gradient descent

# %% [markdown]
# The gradient at $w$ is $g = - \frac{1}{n} \sum_{i=1}^n \frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$

# %%
# Calculate the gradient
# Inputs:
#     w: d-by-1 matrix
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
# Return:
#     g: g: d-by-1 matrix, full gradient
def gradient(w, x, y, lam):
    n, d = x.shape
    yx = numpy.multiply(y, x) # n-by-d matrix
    yxw = numpy.dot(yx, w) # n-by-1 matrix
    vec1 = numpy.exp(yxw) # n-by-1 matrix
    vec2 = numpy.divide(yx, 1+vec1) # n-by-d matrix
    vec3 = -numpy.mean(vec2, axis=0).reshape(d, 1) # d-by-1 matrix
    g = vec3 + lam * w
    return g

# %%
# Gradient descent for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_iter: integer, the maximal iterations
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: d-by-1 matrix, the solution
#     objvals: a record of each iteration's objective value
def grad_descent(x, y, lam, stepsize, max_iter=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_iter) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_iter):
        objval = objective(w, x, y, lam)
        objvals[t] = objval
        print('Objective value at t=' + str(t) + ' is ' + str(objval))
        g = gradient(w, x, y, lam)
        w -= stepsize * g
    
    return w, objvals

# %% [markdown]
# Run gradient descent.

# %%
lam = 1E-6
stepsize = 1.0
w, objvals_gd = grad_descent(x_train, y_train, lam, stepsize)
# Out:
# Objective value at t=0 is 0.6931471805599453
# Objective value at t=1 is 0.5898911284015463
# Objective value at t=2 is 0.5492418679147768
# Objective value at t=3 is 0.5277931236925474
# Objective value at t=4 is 0.5145939498638313
# Objective value at t=5 is 0.505756136789282
# Objective value at t=6 is 0.49952394002419415
# Objective value at t=7 is 0.49497327099947175
# Objective value at t=8 is 0.4915655443965829
# Objective value at t=9 is 0.48896395416948557
# Objective value at t=10 is 0.4869469778383341
# Objective value at t=11 is 0.4853633330115071
# Objective value at t=12 is 0.4841066479383529
# Objective value at t=13 is 0.4831003538085965
# Objective value at t=14 is 0.4822882523304742
# Objective value at t=15 is 0.48162840981878474
# Objective value at t=16 is 0.48108908714734444
# Objective value at t=17 is 0.48064595988889625
# Objective value at t=18 is 0.4802801798773867
# Objective value at t=19 is 0.47997699891339246
# Objective value at t=20 is 0.47972477589005447
# Objective value at t=21 is 0.47951425022700594
# Objective value at t=22 is 0.47933800328383996
# Objective value at t=23 is 0.47919005441133067
# Objective value at t=24 is 0.479065554723674
# Objective value at t=25 is 0.47896055266599263
# Objective value at t=26 is 0.4788718129245366
# Objective value at t=27 is 0.478796675382726
# Objective value at t=28 is 0.4787329444308729
# Objective value at t=29 is 0.47867880148908104
# Objective value at t=30 is 0.47863273542999707
# Objective value at t=31 is 0.478593486910677
# Objective value at t=32 is 0.47856000358992673
# Objective value at t=33 is 0.47853140392140575
# Objective value at t=34 is 0.47850694774456864
# Objective value at t=35 is 0.4784860122950141
# Objective value at t=36 is 0.47846807255832546
# Objective value at t=37 is 0.4784526851223051
# Objective value at t=38 is 0.4784394748598772
# Objective value at t=39 is 0.478428123912156
# Objective value at t=40 is 0.4784183625480161
# Objective value at t=41 is 0.4784099615601781
# Objective value at t=42 is 0.47840272592374405
# Objective value at t=43 is 0.4783964894953062
# Objective value at t=44 is 0.4783911105723069
# Objective value at t=45 is 0.47838646816553804
# Objective value at t=46 is 0.4783824588643605
# Objective value at t=47 is 0.4783789941957413
# Objective value at t=48 is 0.47837599839564193
# Objective value at t=49 is 0.478373406525453
# Objective value at t=50 is 0.4783711628777284
# Objective value at t=51 is 0.4783692196249291
# Objective value at t=52 is 0.47836753567264567
# Objective value at t=53 is 0.4783660756851615
# Objective value at t=54 is 0.47836480925649294
# Objective value at t=55 is 0.4783637102044082
# Objective value at t=56 is 0.4783627559685488
# Objective value at t=57 is 0.47836192709678865
# Objective value at t=58 is 0.4783612068064765
# Objective value at t=59 is 0.47836058060930164
# Objective value at t=60 is 0.478360035990277
# Objective value at t=61 is 0.47835956213280156
# Objective value at t=62 is 0.47835914968299686
# Objective value at t=63 is 0.4783587905475541
# Objective value at t=64 is 0.47835847772019147
# Objective value at t=65 is 0.47835820513257143
# Objective value at t=66 is 0.4783579675261352
# Objective value at t=67 is 0.47835776034184985
# Objective value at t=68 is 0.4783575796252995
# Objective value at t=69 is 0.4783574219449353
# Objective value at t=70 is 0.4783572843216145
# Objective value at t=71 is 0.47835716416783547
# Objective value at t=72 is 0.4783570592353021
# Objective value at t=73 is 0.4783569675696515
# Objective value at t=74 is 0.47835688747134447
# Objective value at t=75 is 0.4783568174618608
# Objective value at t=76 is 0.4783567562544659
# Objective value at t=77 is 0.4783567027289167
# Objective value at t=78 is 0.47835665590956633
# Objective value at t=79 is 0.478356614946399
# Objective value at t=80 is 0.47835657909859863
# Objective value at t=81 is 0.47835654772030317
# Objective value at t=82 is 0.4783565202482501
# Objective value at t=83 is 0.47835649619105636
# Objective value at t=84 is 0.4783564751199126
# Objective value at t=85 is 0.47835645666050186
# Objective value at t=86 is 0.478356440485979
# Objective value at t=87 is 0.47835642631086883
# Objective value at t=88 is 0.4783564138857594
# Objective value at t=89 is 0.47835640299268867
# Objective value at t=90 is 0.47835639344112757
# Objective value at t=91 is 0.47835638506448525
# Objective value at t=92 is 0.4783563777170649
# Objective value at t=93 is 0.47835637127141256
# Objective value at t=94 is 0.4783563656160069
# Objective value at t=95 is 0.47835636065324477
# Objective value at t=96 is 0.47835635629768586
# Objective value at t=97 is 0.47835635247452046
# Objective value at t=98 is 0.47835634911823355
# Objective value at t=99 is 0.478356346171438

# %% [markdown]
# ## 3.2. Stochastic gradient descent (SGD)
#
# Define $Q_i (w) = \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $.
#
# The stochastic gradient at $w$ is $g_i = \frac{\partial Q_i }{ \partial w} = -\frac{y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_i and the gradient of Q_i
# Inputs:
#     w: d-by-1 matrix
#     xi: 1-by-d matrix
#     yi: scalar
#     lam: scalar, the regularization parameter
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def stochastic_objective_gradient(w, xi, yi, lam):
    d = xi.shape[0]
    yx = yi * xi # 1-by-d matrix
    yxw = float(numpy.dot(yx, w)) # scalar
    
    # calculate objective function Q_i
    loss = numpy.log(1 + numpy.exp(-yxw)) # scalar
    reg = lam / 2 * numpy.sum(w * w) # scalar
    obj = loss + reg
    
    # calculate stochastic gradient
    g_loss = -yx.T / (1 + numpy.exp(yxw)) # d-by-1 matrix
    g = g_loss + lam * w # d-by-1 matrix
    
    return obj, g

# %%
# SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def sgd(x, y, lam, stepsize, max_epoch=100, w=None):
    n, d = x.shape
    objvals = numpy.zeros(max_epoch) # store the objective values
    if w is None:
        w = numpy.zeros((d, 1)) # zero initialization
    
    for t in range(max_epoch):
        # randomly shuffle the samples
        rand_indices = numpy.random.permutation(n)
        x_rand = x[rand_indices, :]
        y_rand = y[rand_indices, :]
        
        objval = 0 # accumulate the objective values
        for i in range(n):
            xi = x_rand[i, :] # 1-by-d matrix
            yi = float(y_rand[i, :]) # scalar
            obj, g = stochastic_objective_gradient(w, xi, yi, lam)
            objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size
        objval /= n
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
    
    return w, objvals

# %% [markdown]
# Run SGD.

# %%
lam = 1E-6
stepsize = 0.1
w, objvals_sgd = sgd(x_train, y_train, lam, stepsize)
# Out:
# Objective value at epoch t=0 is 0.525634662750095
# Objective value at epoch t=1 is 0.5178314163835983
# Objective value at epoch t=2 is 0.5201673540312888
# Objective value at epoch t=3 is 0.5114593734731475
# Objective value at epoch t=4 is 0.5043376764278854
# Objective value at epoch t=5 is 0.515522968560638
# Objective value at epoch t=6 is 0.5088954156081418
# Objective value at epoch t=7 is 0.5098592211980896
# Objective value at epoch t=8 is 0.5028408599593752
# Objective value at epoch t=9 is 0.4981130294374532
# Objective value at epoch t=10 is 0.49735463991904477
# Objective value at epoch t=11 is 0.49881470222938995
# Objective value at epoch t=12 is 0.49664530923145556
# Objective value at epoch t=13 is 0.49364054906793225
# Objective value at epoch t=14 is 0.4920009940059208
# Objective value at epoch t=15 is 0.49274326508640653
# Objective value at epoch t=16 is 0.48936479372325586
# Objective value at epoch t=17 is 0.4886347367904884
# Objective value at epoch t=18 is 0.488651093413487
# Objective value at epoch t=19 is 0.4872588705517426
# Objective value at epoch t=20 is 0.48692868590374017
# Objective value at epoch t=21 is 0.48575152262166454
# Objective value at epoch t=22 is 0.4851095108165723
# Objective value at epoch t=23 is 0.4841314064703116
# Objective value at epoch t=24 is 0.48391113132304664
# Objective value at epoch t=25 is 0.48298097903891274
# Objective value at epoch t=26 is 0.482913296757456
# Objective value at epoch t=27 is 0.4826962865111086
# Objective value at epoch t=28 is 0.4821390024884322
# Objective value at epoch t=29 is 0.48181327188495493
# Objective value at epoch t=30 is 0.48150617779592464
# Objective value at epoch t=31 is 0.4808625427776915
# Objective value at epoch t=32 is 0.4809480164143592
# Objective value at epoch t=33 is 0.4806915886364756
# Objective value at epoch t=34 is 0.4803377683286672
# Objective value at epoch t=35 is 0.48025197030965555
# Objective value at epoch t=36 is 0.48004070328203985
# Objective value at epoch t=37 is 0.47988450856599013
# Objective value at epoch t=38 is 0.47970159843911614
# Objective value at epoch t=39 is 0.4795935520573235
# Objective value at epoch t=40 is 0.47945115657807785
# Objective value at epoch t=41 is 0.47937354049426206
# Objective value at epoch t=42 is 0.4792528913666832
# Objective value at epoch t=43 is 0.4791842855198408
# Objective value at epoch t=44 is 0.4791012152065327
# Objective value at epoch t=45 is 0.47902342615028665
# Objective value at epoch t=46 is 0.47895982250901453
# Objective value at epoch t=47 is 0.47889700520081496
# Objective value at epoch t=48 is 0.47884538839684676
# Objective value at epoch t=49 is 0.4787980491510922
# Objective value at epoch t=50 is 0.47875277085062534
# Objective value at epoch t=51 is 0.4787129816679842
# Objective value at epoch t=52 is 0.47867513093335257
# Objective value at epoch t=53 is 0.478645698276379
# Objective value at epoch t=54 is 0.47861728111163826
# Objective value at epoch t=55 is 0.4785915777202464
# Objective value at epoch t=56 is 0.4785678460557226
# Objective value at epoch t=57 is 0.47854659614717054
# Objective value at epoch t=58 is 0.4785278082806606
# Objective value at epoch t=59 is 0.4785108440777788
# Objective value at epoch t=60 is 0.4784953948705891
# Objective value at epoch t=61 is 0.4784814946478546
# Objective value at epoch t=62 is 0.4784690671759814
# Objective value at epoch t=63 is 0.47845785817218445
# Objective value at epoch t=64 is 0.47844778082264483
# Objective value at epoch t=65 is 0.47843860115585857
# Objective value at epoch t=66 is 0.47843038209108346
# Objective value at epoch t=67 is 0.4784230952643381
# Objective value at epoch t=68 is 0.4784164627077357
# Objective value at epoch t=69 is 0.47841048743745934
# Objective value at epoch t=70 is 0.47840511621463017
# Objective value at epoch t=71 is 0.47840024025949485
# Objective value at epoch t=72 is 0.4783958981365625
# Objective value at epoch t=73 is 0.4783919761479741
# Objective value at epoch t=74 is 0.47838844971598105
# Objective value at epoch t=75 is 0.47838525814193755
# Objective value at epoch t=76 is 0.47838241057613456
# Objective value at epoch t=77 is 0.47837981651101036
# Objective value at epoch t=78 is 0.4783775107518914
# Objective value at epoch t=79 is 0.47837542247083753
# Objective value at epoch t=80 is 0.47837354456847
# Objective value at epoch t=81 is 0.4783718545340652
# Objective value at epoch t=82 is 0.4783703298289379
# Objective value at epoch t=83 is 0.4783689646573436
# Objective value at epoch t=84 is 0.47836773016684636
# Objective value at epoch t=85 is 0.47836662083852993
# Objective value at epoch t=86 is 0.47836562328159066
# Objective value at epoch t=87 is 0.47836472489955745
# Objective value at epoch t=88 is 0.4783639162975568
# Objective value at epoch t=89 is 0.47836318858075433
# Objective value at epoch t=90 is 0.4783625318872361
# Objective value at epoch t=91 is 0.47836194346391325
# Objective value at epoch t=92 is 0.47836141251589054
# Objective value at epoch t=93 is 0.4783609351870942
# Objective value at epoch t=94 is 0.4783605054651792
# Objective value at epoch t=95 is 0.47836011820592705
# Objective value at epoch t=96 is 0.47835977035763416
# Objective value at epoch t=97 is 0.4783594568187971
# Objective value at epoch t=98 is 0.4783591748414092
# Objective value at epoch t=99 is 0.47835892095509924

# %% [markdown]
# # 4. Compare GD with SGD
#
# Plot objective function values against epochs.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(6, 4))

epochs_gd = range(len(objvals_gd))
epochs_sgd = range(len(objvals_sgd))

line0, = plt.plot(epochs_gd, objvals_gd, '--b', LineWidth=4)
line1, = plt.plot(epochs_sgd, objvals_sgd, '-r', LineWidth=2)
plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1], ['GD', 'SGD'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_gd_sgd.pdf', format='pdf', dpi=1200)

# %% [markdown]
# # 5. Prediction

# %%
# Predict class label
# Inputs:
#     w: d-by-1 matrix
#     X: m-by-d matrix
# Return:
#     f: m-by-1 matrix, the predictions
def predict(w, X):
    xw = numpy.dot(X, w)
    f = numpy.sign(xw)
    return f

# %%
# evaluate training error
f_train = predict(w, x_train)
diff = numpy.abs(f_train - y_train) / 2
error_train = numpy.mean(diff)
print('Training classification error is ' + str(error_train))
# Out:
# Training classification error is 0.225

# %%
# evaluate test error
f_test = predict(w, x_test)
diff = numpy.abs(f_test - y_test) / 2
error_test = numpy.mean(diff)
print('Test classification error is ' + str(error_test))
# Out:
# Test classification error is 0.203125

# %% [markdown]
# # 6. Mini-batch SGD (fill the code)

# %% [markdown]
# ## 6.1. Compute the objective $Q_I$ and its gradient using a batch of samples
#
# Define $Q_I (w) = \frac{1}{b} \sum_{i \in I} \log \Big( 1 + \exp \big( - y_i x_i^T w \big) \Big) + \frac{\lambda}{2} \| w \|_2^2 $, where $I$ is a set containing $b$ indices randomly drawn from $\{ 1, \cdots , n \}$ without replacement.
#
# The stochastic gradient at $w$ is $g_I = \frac{\partial Q_I }{ \partial w} = \frac{1}{b} \sum_{i \in I} \frac{- y_i x_i }{1 + \exp ( y_i x_i^T w)} + \lambda w$.

# %%
# Calculate the objective Q_I and the gradient of Q_I
# Inputs:
#     w: d-by-1 matrix
#     xi: b-by-d matrix
#     yi: b-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
# Return:
#     obj: scalar, the objective Q_i
#     g: d-by-1 matrix, gradient of Q_i
def mb_stochastic_objective_gradient(w, xi, yi, lam, b):
    # Fill the function
    # Follow the implementation of stochastic_objective_gradient
    # Use matrix-vector multiplication; do not use FOR LOOP of vector-vector multiplications
    d = xi.shape[0]
    
    yx = np.dot(yi.T,xi) 
    yxw = np.dot(yx, w)
    
    loss = np.sum(np.log(1 + np.exp(-yxw)))
    reg = lam / 2 * np.sum(w * w)
    obj = (1 / b) * loss + reg 
    
    g_loss = np.sum(-yx.T / (1 + np.exp(yxw)))
    g = (1 / b) * g_loss + lam * w
    
    return obj, g

# %% [markdown]
# ## 6.2. Implement mini-batch SGD
#
# Hints:
# 1. In every epoch, randomly permute the $n$ samples (just like SGD).
# 2. Each epoch has $\frac{n}{b}$ iterations. In every iteration, use $b$ samples, and compute the gradient and objective using the ``mb_stochastic_objective_gradient`` function. In the next iteration, use the next $b$ samples, and so on.

# %%
# Mini-Batch SGD for solving logistic regression
# Inputs:
#     x: n-by-d matrix
#     y: n-by-1 matrix
#     lam: scalar, the regularization parameter
#     b: integer, the batch size
#     stepsize: scalar
#     max_epoch: integer, the maximal epochs
#     w: d-by-1 matrix, initialization of w
# Return:
#     w: the solution
#     objvals: record of each iteration's objective value
def mb_sgd(x, y, lam, b, stepsize, max_epoch=100, w=None):
    # Fill the function
    # Follow the implementation of sgd
    # Record one objective value per epoch (not per iteration!)
    n, d = x.shape 
    objvals = np.zeros(max_epoch) 
    
    if w is None:
        w = np.zeros((d,1)) 
    
    for t in range(max_epoch):
        rand_indices = np.random.permutation(n)
        x_rand = x[rand_indices, :] 
        y_rand = y[rand_indices, :] 
        
        objval = 0 
        for i in range(n): 
            xi = x_rand[i:i+b] 
            yi = y_rand[i:i+b] 
            for j in range(b):
                obj, g = mb_stochastic_objective_gradient(w, xi, yi, lam, b) 
                objval += obj
            w -= stepsize * g
        
        stepsize *= 0.9 # decrease step size, will be tuned later on
        objval /= n
        objvals[t] = objval
        print('Objective value at epoch t=' + str(t) + ' is ' + str(objval))
            
    return w, objvals

# %% [markdown]
# ## 6.3. Run MB-SGD

# %%
# MB-SGD with batch size b=8
lam = 1E-6 # do not change
b = 8 # do not change
stepsize = 0.000024 # you must tune this parameter

w, objvals_mbsgd8 = mb_sgd(x_train, y_train, lam, b, stepsize)
# Out:
# Objective value at epoch t=0 is 0.6676499097592324
# Objective value at epoch t=1 is 0.6256085243915788
# Objective value at epoch t=2 is 0.5935686513718967
# Objective value at epoch t=3 is 0.5696534660805082
# Objective value at epoch t=4 is 0.55010788386396
# Objective value at epoch t=5 is 0.5362174930052065
# Objective value at epoch t=6 is 0.5280341016264641
# Objective value at epoch t=7 is 0.5282868811575482
# Objective value at epoch t=8 is 0.5076733276456068
# Objective value at epoch t=9 is 0.5033796785230313
# Objective value at epoch t=10 is 0.5039910965352076
# Objective value at epoch t=11 is 0.49954100650273575
# Objective value at epoch t=12 is 0.4854961273332695
# Objective value at epoch t=13 is 0.4928728048061237
# Objective value at epoch t=14 is 0.48112562185479346
# Objective value at epoch t=15 is 0.47884097646333423
# Objective value at epoch t=16 is 0.4778398948887287
# Objective value at epoch t=17 is 0.4743790544484714
# Objective value at epoch t=18 is 0.47327500726348193
# Objective value at epoch t=19 is 0.4646884049756316
# Objective value at epoch t=20 is 0.4603666287955832
# Objective value at epoch t=21 is 0.477326116632742
# Objective value at epoch t=22 is 0.47195217867814765
# Objective value at epoch t=23 is 0.46078261288260663
# Objective value at epoch t=24 is 0.4661293141293849
# Objective value at epoch t=25 is 0.4631777583199802
# Objective value at epoch t=26 is 0.46422606981733916
# Objective value at epoch t=27 is 0.4717322749735107
# Objective value at epoch t=28 is 0.47152997383477613
# Objective value at epoch t=29 is 0.4689130477968974
# Objective value at epoch t=30 is 0.4753841164919631
# Objective value at epoch t=31 is 0.475913541189974
# Objective value at epoch t=32 is 0.47679330268478715
# Objective value at epoch t=33 is 0.45662935648283165
# Objective value at epoch t=34 is 0.4650591902736393
# Objective value at epoch t=35 is 0.4564027106491576
# Objective value at epoch t=36 is 0.46517201255829876
# Objective value at epoch t=37 is 0.455203265784467
# Objective value at epoch t=38 is 0.4490173360564363
# Objective value at epoch t=39 is 0.4584748368323825
# Objective value at epoch t=40 is 0.450900685572366
# Objective value at epoch t=41 is 0.45790490897794844
# Objective value at epoch t=42 is 0.463028294207775
# Objective value at epoch t=43 is 0.4634919113654029
# Objective value at epoch t=44 is 0.4766882521976451
# Objective value at epoch t=45 is 0.47736320860831405
# Objective value at epoch t=46 is 0.47179663711731906
# Objective value at epoch t=47 is 0.45648353483210274
# Objective value at epoch t=48 is 0.46113372872372943
# Objective value at epoch t=49 is 0.4613350666669412
# Objective value at epoch t=50 is 0.4483103871981446
# Objective value at epoch t=51 is 0.4675855177036129
# Objective value at epoch t=52 is 0.45985907771558965
# Objective value at epoch t=53 is 0.46032600406588287
# Objective value at epoch t=54 is 0.47063506404238026
# Objective value at epoch t=55 is 0.46411763171598286
# Objective value at epoch t=56 is 0.4590544390625645
# Objective value at epoch t=57 is 0.46274470242906485
# Objective value at epoch t=58 is 0.46294504006740345
# Objective value at epoch t=59 is 0.4564408927025009
# Objective value at epoch t=60 is 0.4708611358932383
# Objective value at epoch t=61 is 0.4562344602476176
# Objective value at epoch t=62 is 0.46725215993861147
# Objective value at epoch t=63 is 0.4602615635299879
# Objective value at epoch t=64 is 0.4585886609215241
# Objective value at epoch t=65 is 0.46174073028929213
# Objective value at epoch t=66 is 0.4677559864243518
# Objective value at epoch t=67 is 0.4602745326055889
# Objective value at epoch t=68 is 0.46521025072663347
# Objective value at epoch t=69 is 0.4716911868727277
# Objective value at epoch t=70 is 0.46595796230994024
# Objective value at epoch t=71 is 0.45219504986497683
# Objective value at epoch t=72 is 0.45690370642289774
# Objective value at epoch t=73 is 0.47139249049033793
# Objective value at epoch t=74 is 0.4526379427923355
# Objective value at epoch t=75 is 0.45128287393360866
# Objective value at epoch t=76 is 0.45767017070807026
# Objective value at epoch t=77 is 0.467760183723406
# Objective value at epoch t=78 is 0.4595035714246234
# Objective value at epoch t=79 is 0.46959136224106823
# Objective value at epoch t=80 is 0.4592204654318307
# Objective value at epoch t=81 is 0.46171941234847286
# Objective value at epoch t=82 is 0.46195943764591024
# Objective value at epoch t=83 is 0.46791361576176493
# Objective value at epoch t=84 is 0.4641199060469104
# Objective value at epoch t=85 is 0.46819856242565183
# Objective value at epoch t=86 is 0.4575281350325147
# Objective value at epoch t=87 is 0.4603825786258657
# Objective value at epoch t=88 is 0.46170248198153674
# Objective value at epoch t=89 is 0.46224743138291585
# Objective value at epoch t=90 is 0.4549947600865022
# Objective value at epoch t=91 is 0.466020968521478
# Objective value at epoch t=92 is 0.4715068278189946
# Objective value at epoch t=93 is 0.4693762385073443
# Objective value at epoch t=94 is 0.4604534396239949
# Objective value at epoch t=95 is 0.4652700517274611
# Objective value at epoch t=96 is 0.47276675852814787
# Objective value at epoch t=97 is 0.4564597850560368
# Objective value at epoch t=98 is 0.46674402514596014
# Objective value at epoch t=99 is 0.4737489960626816

# %%
# MB-SGD with batch size b=64
lam = 1E-6 # do not change
b = 64 # do not change
stepsize = 0.0000018 # you must tune this parameter

w, objvals_mbsgd64 = mb_sgd(x_train, y_train, lam, b, stepsize)
# Out:
# Objective value at epoch t=0 is 0.6798299785871431
# Objective value at epoch t=1 is 0.6498213187496769
# Objective value at epoch t=2 is 0.6283430182325345
# Objective value at epoch t=3 is 0.6129921169240451
# Objective value at epoch t=4 is 0.5946909242252801
# Objective value at epoch t=5 is 0.5801926016315914
# Objective value at epoch t=6 is 0.5706117448364209
# Objective value at epoch t=7 is 0.5579481305664914
# Objective value at epoch t=8 is 0.5502139597950009
# Objective value at epoch t=9 is 0.5349916005896698
# Objective value at epoch t=10 is 0.5312288201600778
# Objective value at epoch t=11 is 0.5256337244036736
# Objective value at epoch t=12 is 0.5227028462340584
# Objective value at epoch t=13 is 0.5184245279037749
# Objective value at epoch t=14 is 0.5090698161871537
# Objective value at epoch t=15 is 0.5096324623912218
# Objective value at epoch t=16 is 0.5090223322266196
# Objective value at epoch t=17 is 0.5036121995412213
# Objective value at epoch t=18 is 0.49820641790427905
# Objective value at epoch t=19 is 0.49421021656076025
# Objective value at epoch t=20 is 0.49628783846439123
# Objective value at epoch t=21 is 0.49465340224321847
# Objective value at epoch t=22 is 0.49107650670631103
# Objective value at epoch t=23 is 0.4879231973763335
# Objective value at epoch t=24 is 0.4901263438718154
# Objective value at epoch t=25 is 0.4883243494270112
# Objective value at epoch t=26 is 0.4867656046557614
# Objective value at epoch t=27 is 0.4892274677914437
# Objective value at epoch t=28 is 0.4907945328868656
# Objective value at epoch t=29 is 0.4844137644666476
# Objective value at epoch t=30 is 0.4793211574008608
# Objective value at epoch t=31 is 0.4898793274541774
# Objective value at epoch t=32 is 0.4828242933770084
# Objective value at epoch t=33 is 0.47901872692107544
# Objective value at epoch t=34 is 0.476216342482369
# Objective value at epoch t=35 is 0.4811192666477521
# Objective value at epoch t=36 is 0.47894604895383874
# Objective value at epoch t=37 is 0.48591268538873367
# Objective value at epoch t=38 is 0.4860505080396522
# Objective value at epoch t=39 is 0.47449340012098895
# Objective value at epoch t=40 is 0.4797084883218865
# Objective value at epoch t=41 is 0.47460108600835066
# Objective value at epoch t=42 is 0.4707930385838338
# Objective value at epoch t=43 is 0.47441620167922915
# Objective value at epoch t=44 is 0.47122718319877965
# Objective value at epoch t=45 is 0.47794733896276975
# Objective value at epoch t=46 is 0.4788840653268527
# Objective value at epoch t=47 is 0.4678833373841009
# Objective value at epoch t=48 is 0.48076290361286655
# Objective value at epoch t=49 is 0.47253962114288656
# Objective value at epoch t=50 is 0.4803341074041854
# Objective value at epoch t=51 is 0.47538470952635653
# Objective value at epoch t=52 is 0.48229807794051016
# Objective value at epoch t=53 is 0.481021863869506
# Objective value at epoch t=54 is 0.4721054704854752
# Objective value at epoch t=55 is 0.46687233751924556
# Objective value at epoch t=56 is 0.4850312400048883
# Objective value at epoch t=57 is 0.4804937001246848
# Objective value at epoch t=58 is 0.47440895171832514
# Objective value at epoch t=59 is 0.475158226724323
# Objective value at epoch t=60 is 0.47703470681123017
# Objective value at epoch t=61 is 0.4759370679411844
# Objective value at epoch t=62 is 0.4718602284762037
# Objective value at epoch t=63 is 0.4703560716170572
# Objective value at epoch t=64 is 0.47470362373327885
# Objective value at epoch t=65 is 0.4837364724309657
# Objective value at epoch t=66 is 0.47734556927658095
# Objective value at epoch t=67 is 0.48185936636764753
# Objective value at epoch t=68 is 0.4733530026350695
# Objective value at epoch t=69 is 0.4725858878367576
# Objective value at epoch t=70 is 0.478006921125296
# Objective value at epoch t=71 is 0.47241196558372167
# Objective value at epoch t=72 is 0.4844827015300261
# Objective value at epoch t=73 is 0.4771612528487784
# Objective value at epoch t=74 is 0.46872079175494347
# Objective value at epoch t=75 is 0.47504478358463215
# Objective value at epoch t=76 is 0.475415653163129
# Objective value at epoch t=77 is 0.4744043966356662
# Objective value at epoch t=78 is 0.46883692711212255
# Objective value at epoch t=79 is 0.4753875110428164
# Objective value at epoch t=80 is 0.4728548012753757
# Objective value at epoch t=81 is 0.4716374310878571
# Objective value at epoch t=82 is 0.47669056900270956
# Objective value at epoch t=83 is 0.47889390417260075
# Objective value at epoch t=84 is 0.4831903116491011
# Objective value at epoch t=85 is 0.4816053338397701
# Objective value at epoch t=86 is 0.47634508231014416
# Objective value at epoch t=87 is 0.4706132551351604
# Objective value at epoch t=88 is 0.4667548504767671
# Objective value at epoch t=89 is 0.48082728136543984
# Objective value at epoch t=90 is 0.4797176102677758
# Objective value at epoch t=91 is 0.4725134171324587
# Objective value at epoch t=92 is 0.4833971514305711
# Objective value at epoch t=93 is 0.48234832396769517
# Objective value at epoch t=94 is 0.481874996428698
# Objective value at epoch t=95 is 0.47957423787002956
# Objective value at epoch t=96 is 0.474919285836218
# Objective value at epoch t=97 is 0.4809820662201235
# Objective value at epoch t=98 is 0.47444585590909555
# Objective value at epoch t=99 is 0.4772760012753433

# %% [markdown]
# # 7. Plot and compare GD, SGD, and MB-SGD

# %% [markdown]
# You are required to compare the following algorithms:
#
# - Gradient descent (GD)
#
# - SGD
#
# - MB-SGD with b=8
#
# - MB-SGD with b=64
#
# Follow the code in Section 4 to plot ```objective function value``` against ```epochs```. There should be four curves in the plot; each curve corresponds to one algorithm.

# %% [markdown]
# Hint: Logistic regression with $\ell_2$-norm regularization is a strongly convex optimization problem. All the algorithms will converge to the same solution. **In the end, the ``objective function value`` of the 4 algorithms will be the same. If not the same, your implementation must be wrong. Do NOT submit wrong code and wrong result!**

# %%
# plot the 4 curves:
fig = plt.figure(figsize=(6, 4))

epochs_gd = range(len(objvals_gd))
epochs_sgd = range(len(objvals_sgd))
epochs_mbsgd8 = range(len(objvals_mbsgd8))
epochs_mbsgd64 = range(len(objvals_mbsgd64))

line0, = plt.plot(epochs_gd, objvals_gd, '--b', LineWidth=4)
line1, = plt.plot(epochs_sgd, objvals_sgd, '-r', LineWidth=2)
line2, = plt.plot(epochs_mbsgd8, objvals_mbsgd8, ':g', LineWidth=1.5)
line3, = plt.plot(epochs_mbsgd64, objvals_mbsgd64, '-.y', LineWidth=5)


plt.xlabel('Epochs', FontSize=20)
plt.ylabel('Objective Value', FontSize=20)
plt.xticks(FontSize=16)
plt.yticks(FontSize=16)
plt.legend([line0, line1, line2, line3], ['GD', 'SGD', 'MBSGD8', 'MBSGD64'], fontsize=20)
plt.tight_layout()
plt.show()
fig.savefig('compare_gd_sgd_mbsgd.pdf', format='pdf', dpi=1200)

# %%
import numpy as np
yx = np.random.randn(91,9)
w = np.random.randn(2,1)

result = np.multiply(yx,w)
result.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eed58c2b0b4c> in <module>
# ----> 1 yx = np.random.randn(91,9)
#       2 w = np.random.randn(2,1)
#       3
#       4 result = np.multiply(yx,w)
#       5 result.shape
#
# NameError: name 'np' is not defined
