# %%
import numpy as np
yx = np.random.randn(768,1)
vec1 = np.random.randn(768,1)
vec2 = np.divide(yx, 1 + vec1)
vec2.shape
# Out:
# (768, 1)

# %%
d = 9
w = np.zeros((d, 1))
lam = 1E-6
vec3 = -np.sum(vec2, axis=0).reshape(d,1)
g = vec3 + lam * w
g.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-57ff382e9161> in <module>
#       2 w = np.zeros((d, 1))
#       3 lam = 1E-6
# ----> 4 vec3 = -np.sum(vec2, axis=0).reshape(d,1)
#       5 g = vec3 + lam * w
#       6 g.shape
#
# ValueError: cannot reshape array of size 1 into shape (9,1)
